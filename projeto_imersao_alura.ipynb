# %%
# !pip install -q -U google-generativeai

import google.generativeai as genai
genai.configure(api_key='SUA_API_KEY')

# Função para realizar o teste e retornar as áreas de maior aptidão
def realizar_teste():
  areas = {'a': 0, 'b': 0, 'c': 0, 'd': 0}

  print("**Seção 1: Lógica e Resolução de Problemas**")
  respostas = input("""
  1.  Ao se deparar com um problema complexo, você:
      a) Divide o problema em partes menores e busca soluções individuais.
      b)  Testa diferentes abordagens até encontrar uma que funcione.
      c) Analisa o problema a fundo para entender sua causa raiz antes de buscar soluções.
      d) Prefere pedir ajuda a alguém com mais experiência na área.
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  respostas = input("""
  2.  Qual dos seguintes jogos te atrai mais?
      a) Sudoku
      b) Xadrez
      c) Quebra-cabeças
      d) Jogos de construção (Minecraft, Lego, etc.)
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  respostas = input("""
  3.  Você se considera uma pessoa:
      a) Criativa e com facilidade para encontrar soluções inovadoras.
      b)  Metódica e organizada, preferindo seguir processos já estabelecidos.
      c) Curiosa e investigativa, sempre em busca de novos conhecimentos.
      d) Colaborativa e com facilidade para trabalhar em equipe.
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  print("\n**Seção 2:  Tecnologia e Ferramentas**")
  respostas = input("""
  1.  Qual seu nível de familiaridade com linguagens de programação?
      a) Conheço os conceitos básicos e consigo escrever pequenos programas.
      b) Domino pelo menos uma linguagem e consigo desenvolver projetos de média complexidade.
      c) Sou especialista em programação e consigo desenvolver projetos complexos em diferentes linguagens.
      d) Não possuo conhecimento em programação.
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  respostas = input("""
  2.  Você se interessa por:
      a)  Desenvolvimento de aplicativos e softwares.
      b)  Gerenciamento e configuração de redes de computadores.
      c)  Análise de dados e construção de modelos preditivos.
      d)  Configuração e manutenção de servidores e infraestrutura de TI.
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  respostas = input("""
  3.  Qual a sua ferramenta de busca preferida?
      a)  Google
      b)  DuckDuckGo
      c)  Bing
      d)  Ecosia
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  respostas = input("""
  4.  Você utiliza algum sistema de controle de versão (Git, SVN)?
      a)  Sim, utilizo frequentemente.
      b)  Tenho conhecimento básico, mas não utilizo com frequência.
      c)  Já ouvi falar, mas nunca utilizei.
      d)  Não sei o que é um sistema de controle de versão.
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  print("\n**Seção 3: Áreas de Interesse**")
  respostas = input("""
  1.  O que mais te fascina no mundo da tecnologia?
      a) A capacidade de criar soluções inovadoras para problemas reais.
      b) A possibilidade de conectar pessoas e informações através de redes complexas.
      c) A habilidade de extrair conhecimento a partir de grandes volumes de dados.
      d) A garantia de funcionamento e segurança da infraestrutura tecnológica.
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  respostas = input("""
  2.  Qual das áreas abaixo te desperta maior interesse?
      a) Desenvolvimento Web
      b) Cibersegurança
      c) Inteligência Artificial
      d) Cloud Computing
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  respostas = input("""
  3.  Quais perfis você costuma seguir nas redes sociais?
      a) Programadores, desenvolvedores e entusiastas de tecnologia.
      b)  Especialistas em segurança da informação e hackers éticos.
      c)  Cientistas de dados, estatísticos e matemáticos.
      d)  Administradores de sistemas e especialistas em infraestrutura.
  Resposta (a/b/c/d): """)
  areas[respostas.lower()] += 1

  maior_pontuacao = max(areas, key=areas.get)
  areas_de_aptidao = []

  for area, pontuacao in areas.items():
    if pontuacao == areas[maior_pontuacao]:
      if area == 'a':
        areas_de_aptidao.append("Programação")
      elif area == 'b':
        areas_de_aptidao.append("Redes")
      elif area == 'c':
        areas_de_aptidao.append("Ciência de Dados")
      elif area == 'd':
        areas_de_aptidao.append("Infraestrutura")

  return areas_de_aptidao

# Função para gerar sugestões de cursos com base nas áreas de aptidão
def gerar_sugestoes_cursos(areas_de_aptidao):
  prompt = f"Com base nas áreas de aptidão: {', '.join(areas_de_aptidao)}, sugira cursos da Alura, fornecendo o nome completo do curso e o link para ele."
  model = genai.GenerativeModel('gemini-1.5-pro-latest')
  response = model.generate_content([{'text': prompt}])
  return response.text

# --- Fluxo principal ---
areas = realizar_teste()

# Imprime a mensagem com a área de aptidão
for area in areas:
  print(f"Parabéns, você tem uma aptidão para {area}!")

sugestoes = gerar_sugestoes_cursos(areas)
print(f"\nSugestões de cursos da Alura:\n{sugestoes}")
# Out:
# **Seção 1: Lógica e Resolução de Problemas**
#
#   1.  Ao se deparar com um problema complexo, você:
#       a) Divide o problema em partes menores e busca soluções individuais.
#       b)  Testa diferentes abordagens até encontrar uma que funcione.
#       c) Analisa o problema a fundo para entender sua causa raiz antes de buscar soluções.
#       d) Prefere pedir ajuda a alguém com mais experiência na área.
#   Resposta (a/b/c/d): d
#
#   2.  Qual dos seguintes jogos te atrai mais?
#       a) Sudoku
#       b) Xadrez
#       c) Quebra-cabeças
#       d) Jogos de construção (Minecraft, Lego, etc.)
#   Resposta (a/b/c/d): d
#
#   3.  Você se considera uma pessoa:
#       a) Criativa e com facilidade para encontrar soluções inovadoras.
#       b)  Metódica e organizada, preferindo seguir processos já estabelecidos.
#       c) Curiosa e investigativa, sempre em busca de novos conhecimentos.
#       d) Colaborativa e com facilidade para trabalhar em equipe.
#   Resposta (a/b/c/d): d
#
# **Seção 2:  Tecnologia e Ferramentas**
#
#   1.  Qual seu nível de familiaridade com linguagens de programação?
#       a) Conheço os conceitos básicos e consigo escrever pequenos programas.
#       b) Domino pelo menos uma linguagem e consigo desenvolver projetos de média complexidade.
#       c) Sou especialista em programação e consigo desenvolver projetos complexos em diferentes linguagens.
#       d) Não possuo conhecimento em programação.
#   Resposta (a/b/c/d): d
#
#   2.  Você se interessa por:
#       a)  Desenvolvimento de aplicativos e softwares.
#       b)  Gerenciamento e configuração de redes de computadores.
#       c)  Análise de dados e construção de modelos preditivos.
#       d)  Configuração e manutenção de servidores e infraestrutura de TI.
#   Resposta (a/b/c/d): d
#
#   3.  Qual a sua ferramenta de busca preferida?
#       a)  Google
#       b)  DuckDuckGo
#       c)  Bing
#       d)  Ecosia
#   Resposta (a/b/c/d): d
#
#   4.  Você utiliza algum sistema de controle de versão (Git, SVN)?
#       a)  Sim, utilizo frequentemente.
#       b)  Tenho conhecimento básico, mas não utilizo com frequência.
#       c)  Já ouvi falar, mas nunca utilizei.
#       d)  Não sei o que é um sistema de controle de versão.
#   Resposta (a/b/c/d): d
#
# **Seção 3: Áreas de Interesse**
#
#   1.  O que mais te fascina no mundo da tecnologia?
#       a) A capacidade de criar soluções inovadoras para problemas reais.
#       b) A possibilidade de conectar pessoas e informações através de redes complexas.
#       c) A habilidade de extrair conhecimento a partir de grandes volumes de dados.
#       d) A garantia de funcionamento e segurança da infraestrutura tecnológica.
#   Resposta (a/b/c/d): d
#
#   2.  Qual das áreas abaixo te desperta maior interesse?
#       a) Desenvolvimento Web
#       b) Cibersegurança
#       c) Inteligência Artificial
#       d) Cloud Computing
#   Resposta (a/b/c/d): d
#
#   3.  Quais perfis você costuma seguir nas redes sociais?
#       a) Programadores, desenvolvedores e entusiastas de tecnologia.
#       b)  Especialistas em segurança da informação e hackers éticos.
#       c)  Cientistas de dados, estatísticos e matemáticos.
#       d)  Administradores de sistemas e especialistas em infraestrutura.
#   Resposta (a/b/c/d): d
# Parabéns, você tem uma aptidão para Infraestrutura!
#
# Sugestões de cursos da Alura:
# ## Sugestões de cursos da Alura na área de Infraestrutura:
#
# **Nível Iniciante:**
#
# * **Linux I: Conhecendo e utilizando o terminal:** Aprenda os comandos básicos do terminal Linux e navegue pelo sistema operacional com confiança. [https://www.alura.com.br/curso-online-linux-terminal](https://www.alura.com.br/curso-online-linux-terminal)
# * **Redes de computadores: Conceitos básicos:** Entenda os fundamentos de redes, como IPs, protocolos e topologias, para construir uma base sólida. [https://www.alura.com.br/curso-online-redes-computadores-fundamentos](https://www.alura.com.br/curso-online-redes-computadores-fundamentos)
# * **Windows Server: Gerenciando usuários e recursos:** Domine a administração básica do Windows Server, configurando usuários, grupos e permissões. [https://www.alura.com.br/curso-online-windows-server-usuarios-recursos](https://www.alura.com.br/curso-online-windows-server-usuarios-recursos)
# * **Fundamentos de Cloud Computing:** Descubra o universo da nuvem, entendendo os principais conceitos e modelos de serviço como IaaS, PaaS e SaaS. [https://www.alura.com.br/curso-online-cloud-computing](https://www.alura.com.br/curso-online-cloud-computing)
#
# **Nível Intermediário:**
#
# * **Docker: Criando e gerenciando containers:** Mergulhe no mundo da conteinerização com Docker, aprendendo a criar, gerenciar e orquestrar containers. [https://www.alura.com.br/curso-online-docker-criando-containers](https://www.alura.com.br/curso-online-docker-criando-containers)
# * **AWS: Os serviços essenciais:** Explore os principais serviços da Amazon Web Services, como EC2, S3 e VPC, para construir e gerenciar sua infraestrutura na nuvem. [https://www.alura.com.br/curso-online-aws-essencial](https://www.alura.com.br/curso-online-aws-essencial)
# * **Kubernetes: Introdução a orquestração de containers:** Aprenda a orquestrar seus containers com Kubernetes, configurando deployments, services e pods para alta disponibilidade e escalabilidade. [https://www.alura.com.br/curso-online-kubernetes-introducao](https://www.alura.com.br/curso-online-kubernetes-introducao)
# * **Monitoramento de serviços e aplicações:** Implemente ferramentas e técnicas de monitoramento para garantir a saúde e performance da sua infraestrutura. [https://www.alura.com.br/curso-online-monitoramento-servicos-aplicacoes](https://www.alura.com.br/curso-online-monitoramento-servicos-aplicacoes)
#
# **Nível Avançado:**
#
# * **Segurança em ambientes Linux:** Domine as melhores práticas de segurança para proteger seus servidores Linux de ataques e vulnerabilidades. [https://www.alura.com.br/curso-online-seguranca-linux](https://www.alura.com.br/curso-online-seguranca-linux)
# * **Azure DevOps: CI/CD para aplicações .NET:** Implemente pipelines de CI/CD na plataforma Azure DevOps para automatizar o build, teste e deploy de suas aplicações .NET. [https://www.alura.com.br/curso-online-azure-devops-aplicacao-net](https://www.alura.com.br/curso-online-azure-devops-aplicacao-net)
# * **AWS Lambda: Criando funções serverless:** Desenvolva e implemente funções serverless na AWS Lambda para criar microsserviços escaláveis e eficientes. [https://www.alura.com.br/curso-online-aws-lambda](https://www.alura.com.br/curso-online-aws-lambda)
#
# **Formações Completas:**
#
# * **Formação DevOps:** Mergulhe no universo DevOps e domine as ferramentas e práticas para automatizar a entrega de software. [https://www.alura.com.br/formacao-devops](https://www.alura.com.br/formacao-devops)
# * **Formação Segurança da Informação:** Aprenda a proteger sistemas e dados contra ataques e vulnerabilidades, dominando as principais ferramentas e técnicas de segurança. [https://www.alura.com.br/formacao-seguranca-informacao](https://www.alura.com.br/formacao-seguranca-informacao)
#
# Lembre-se de escolher os cursos que melhor se adequam às suas necessidades e objetivos profissionais. A Alura oferece uma variedade de cursos em diferentes níveis de conhecimento, então explore o catálogo e encontre o ideal para você!
